# %% [markdown]
# {/* cspell:ignore nfev */}
#
# # Variational quantum eigensolver
#
# *Usage estimate: 73 minutes on ibm\_kyiv (NOTE: This is an estimate only. Your runtime might vary.)*

# %% [markdown]
# ## Background
#
# [Variational quantum algorithms](https://arxiv.org/abs/2012.09265) are promising candidate hybrid-algorithms for observing quantum computation utility on noisy near-term devices. Variational algorithms are characterized by the use of a classical optimization algorithm to iteratively update a parameterized trial solution, or "ansatz". Chief among these methods is the Variational Quantum Eigensolver (VQE) that aims to solve for the ground state of a given Hamiltonian represented as a linear combination of Pauli terms, with an ansatz circuit where the number of parameters to optimize over is polynomial in the number of qubits.  Given that the size of the full solution vector is exponential in the number of qubits, successful minimization using VQE requires, in general, additional problem-specific information to define the structure of the ansatz circuit.
#
# Executing a VQE algorithm requires the following components:
#
# 1.  Hamiltonian and ansatz (problem specification)
# 2.  Qiskit Runtime estimator
# 3.  Classical optimizer
#
# Although the Hamiltonian and ansatz require domain-specific knowledge to construct, these details are immaterial to the Runtime, and we can execute a wide class of VQE problems in the same manner.

# %% [markdown]
# ## Requirements
#
# Before starting this tutorial, ensure that you have the following installed:
#
# *   Qiskit SDK 1.0 or later, with visualization support (`pip install 'qiskit[visualization]'`)
# *   Qiskit Runtime 0.22 or later(`pip install qiskit-ibm-runtime`)

# %% [markdown]
# ## Setup

# %%
import matplotlib.pyplot as plt
import numpy as np
from qiskit_aer import AerSimulator
from scipy.optimize import minimize

from qiskit.circuit.library import efficient_su2
from qiskit.quantum_info import SparsePauliOp
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

from qiskit_ibm_runtime import QiskitRuntimeService, Session
from qiskit_ibm_runtime import EstimatorV2 as Estimator

# %% [markdown]
# ## Step 1: Map classical inputs to a quantum problem
#
# Although the problem instance in question for the VQE algorithm can come from a variety of domains, the form for execution through Qiskit Runtime is the same. Qiskit provides a convenience class for expressing Hamiltonians in Pauli form, and a collection of widely used ansatz circuits in the [`qiskit.circuit.library`](https://docs.quantum-computing.ibm.com/api/qiskit/circuit_library).
#
# This example Hamiltonian is derived from a quantum chemistry problem.

# %%
# To run on hardware, select the backend with the fewest number of jobs in the queue
# service = QiskitRuntimeService()
# backend = service.least_busy(
#     operational=True, simulator=False, min_num_qubits=127
# )
backend = AerSimulator()

# %%
hamiltonian = SparsePauliOp.from_list(
    [("YZ", 0.3980), ("ZI", -0.3980), ("ZZ", -0.0113), ("XX", 0.1810)]
)

# %% [markdown]
# Our choice of ansatz is the `efficient_su2` that, by default, linearly entangles qubits, making it ideal for quantum hardware with limited connectivity.

# %%
ansatz = efficient_su2(hamiltonian.num_qubits)
ansatz.decompose().draw("mpl", style="iqp")

# %% [markdown]
# From the previous figure we see that our ansatz circuit is defined by a vector of parameters, $\theta_{i}$, with the total number given by:

# %%
num_params = ansatz.num_parameters
num_params
# Out:
# 16

# %% [markdown]
# ## Step 2: Optimize problem for quantum hardware execution

# %% [markdown]
# To reduce the total job execution time, Qiskit primitives only accept circuits (ansatz) and observables (Hamiltonian) that conform to the instructions and connectivity supported by the target QPU (referred to as instruction set architecture (ISA) circuits and observables).

# %% [markdown]
# ### ISA circuit

# %% [markdown]
# Schedule a series of [`qiskit.transpiler`](https://docs.quantum-computing.ibm.com/api/qiskit/transpiler) passes to optimize the circuit for a selected backend and make it compatible with the backend's ISA. This can be easily done with a preset pass manager from `qiskit.transpiler` and its `optimization_level` parameter.
#
# The lowest optimization level does the minimum needed to get the circuit running on the device; it maps the circuit qubits to the device qubits and adds swap gates to allow all two-qubit operations. The highest optimization level is much smarter and uses lots of tricks to reduce the overall gate count. Since multi-qubit gates have high error rates and qubits decohere over time, the shorter circuits should give better results.

# %%
target = backend.target
pm = generate_preset_pass_manager(target=target, optimization_level=3)

ansatz_isa = pm.run(ansatz)

# %%
ansatz_isa.draw(output="mpl", idle_wires=False, style="iqp")

# %% [markdown]
# ### ISA observable

# %% [markdown]
# Transform the Hamiltonian to make it backend-compatible before running jobs with [`Runtime Estimator V2`](/docs/api/qiskit-ibm-runtime/estimator-v2#run). Perform the transformation by using the `apply_layout` method of `SparsePauliOp` object.

# %%
hamiltonian_isa = hamiltonian.apply_layout(layout=ansatz_isa.layout)

# %% [markdown]
# ## Step 3: Execute using Qiskit primitives
#
# Like many classical optimization problems, the solution to a VQE problem can be formulated as minimization of a scalar cost function.  By definition, VQE looks to find the ground state solution to a Hamiltonian by optimizing the ansatz circuit parameters to minimize the expectation value (energy) of the Hamiltonian.  With the Qiskit Runtime [`Estimator`](/docs/api/qiskit-ibm-runtime/estimator-v2) directly taking a Hamiltonian and parameterized ansatz, and returning the necessary energy, the cost function for a VQE instance is quite simple.
#
# Note that the `run()` method of [Qiskit Runtime `EstimatorV2`](/docs/api/qiskit-ibm-runtime/estimator-v2)  takes an iterable of `primitive unified blocs (PUBs)`. Each PUB is an iterable in the format `(circuit, observables, parameter_values: Optional, precision: Optional)`.

# %%
def cost_func(params, ansatz, hamiltonian, estimator):
    """Return estimate of energy from estimator

    Parameters:
        params (ndarray): Array of ansatz parameters
        ansatz (QuantumCircuit): Parameterized ansatz circuit
        hamiltonian (SparsePauliOp): Operator representation of Hamiltonian
        estimator (EstimatorV2): Estimator primitive instance
        cost_history_dict: Dictionary for storing intermediate results

    Returns:
        float: Energy estimate
    """
    pub = (ansatz, [hamiltonian,  SparsePauliOp("ZZ")], [params])
    result = estimator.run(pubs=[pub]).result()
    print(type(result[0].data.evs))
    energy = result[0].data.evs[0]

    cost_history_dict["iters"] += 1
    cost_history_dict["prev_vector"] = params
    cost_history_dict["cost_history"].append(energy)
    print(
        f"Iters. done: {cost_history_dict['iters']} [Current cost: {energy}]"
    )

    return energy

# %% [markdown]
# Note that, in addition to the array of optimization parameters that must be the first argument, we use additional arguments to pass the terms needed in the cost function. We also access a global variable called `cost_history_dict` within this function. This dictionary stores the current vector at each iteration, for example in case you need to restart the routine due to failure, and also returns the current iteration number and average time per iteration.

# %%
cost_history_dict = {
    "prev_vector": None,
    "iters": 0,
    "cost_history": [],
}

# %% [markdown]
# We can now use a classical optimizer of our choice to minimize the cost function. Here, we use the [COBYLA routine from SciPy through the `minimize` function](https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.minimize.html). Note that when running on real quantum hardware, the choice of optimizer is important, as not all optimizers handle noisy cost function landscapes equally well.
#
# To begin the routine, specify a random initial set of parameters:

# %%
x0 = 2 * np.pi * np.random.random(num_params)

# %%
x0
# Out:
# array([5.37763312, 2.27181778, 1.05545373, 0.41061892, 3.7751208 ,
#        4.59010674, 1.86030205, 1.6904559 , 1.46099348, 1.59185175,
#        0.00603519, 3.81656275, 4.48853866, 4.97518487, 2.64480271,
#        3.60448739])

# %% [markdown]
# Because we are sending a large number of jobs that we would like to execute iteratively, we use a [`Session`](https://docs.quantum-computing.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.Session) to execute all the generated circuits in one block.  Here `args` is the standard SciPy way to supply the additional parameters needed by the cost function.

# %%
with Session(backend=backend) as session:
    estimator = Estimator(mode=session)
    estimator.options.default_shots = 10000

    res = minimize(
        cost_func,
        x0,
        args=(ansatz_isa, hamiltonian_isa, estimator),
        method="cobyla",
    )
# Out:
# <class 'numpy.ndarray'>
# Iters. done: 1 [Current cost: 0.020634359999999977]
# <class 'numpy.ndarray'>
# Iters. done: 2 [Current cost: -0.05643900000000002]
# <class 'numpy.ndarray'>
# Iters. done: 3 [Current cost: 0.22266762]
# <class 'numpy.ndarray'>
# Iters. done: 4 [Current cost: -0.04509214000000002]
# <class 'numpy.ndarray'>
# Iters. done: 5 [Current cost: 0.08042664]
# <class 'numpy.ndarray'>
# Iters. done: 6 [Current cost: -0.2619073]
# <class 'numpy.ndarray'>
# Iters. done: 7 [Current cost: -0.25568162000000005]
# <class 'numpy.ndarray'>
# Iters. done: 8 [Current cost: -0.15776370000000003]
# <class 'numpy.ndarray'>
# Iters. done: 9 [Current cost: -0.2600601]
# <class 'numpy.ndarray'>
# Iters. done: 10 [Current cost: -0.25745744000000004]
# <class 'numpy.ndarray'>
# Iters. done: 11 [Current cost: -0.001619820000000001]
# <class 'numpy.ndarray'>
# Iters. done: 12 [Current cost: 0.006653059999999988]
# <class 'numpy.ndarray'>
# Iters. done: 13 [Current cost: -0.26499206000000003]
# <class 'numpy.ndarray'>
# Iters. done: 14 [Current cost: -0.22049031999999996]
# <class 'numpy.ndarray'>
# Iters. done: 15 [Current cost: -0.44947018]
# <class 'numpy.ndarray'>
# Iters. done: 16 [Current cost: -0.5307714600000001]
# <class 'numpy.ndarray'>
# Iters. done: 17 [Current cost: -0.08617058000000001]
# <class 'numpy.ndarray'>
# Iters. done: 18 [Current cost: -0.40576650000000003]
# <class 'numpy.ndarray'>
# Iters. done: 19 [Current cost: -0.45021568]
# <class 'numpy.ndarray'>
# Iters. done: 20 [Current cost: -0.47542604]
# <class 'numpy.ndarray'>
# Iters. done: 21 [Current cost: -0.54262424]
# <class 'numpy.ndarray'>
# Iters. done: 22 [Current cost: -0.46128476]
# <class 'numpy.ndarray'>
# Iters. done: 23 [Current cost: -0.5361016399999999]
# <class 'numpy.ndarray'>
# Iters. done: 24 [Current cost: -0.61087124]
# <class 'numpy.ndarray'>
# Iters. done: 25 [Current cost: -0.45977228]
# <class 'numpy.ndarray'>
# Iters. done: 26 [Current cost: -0.52982404]
# <class 'numpy.ndarray'>
# Iters. done: 27 [Current cost: -0.5044186]
# <class 'numpy.ndarray'>
# Iters. done: 28 [Current cost: -0.45856554]
# <class 'numpy.ndarray'>
# Iters. done: 29 [Current cost: -0.56642644]
# <class 'numpy.ndarray'>
# Iters. done: 30 [Current cost: -0.62822142]
# <class 'numpy.ndarray'>
# Iters. done: 31 [Current cost: -0.5547885800000001]
# <class 'numpy.ndarray'>
# Iters. done: 32 [Current cost: -0.64973676]
# <class 'numpy.ndarray'>
# Iters. done: 33 [Current cost: -0.42883254000000004]
# <class 'numpy.ndarray'>
# Iters. done: 34 [Current cost: -0.60974068]
# <class 'numpy.ndarray'>
# Iters. done: 35 [Current cost: -0.57200506]
# <class 'numpy.ndarray'>
# Iters. done: 36 [Current cost: -0.44721424]
# <class 'numpy.ndarray'>
# Iters. done: 37 [Current cost: -0.5672006800000001]
# <class 'numpy.ndarray'>
# Iters. done: 38 [Current cost: -0.62409364]
# <class 'numpy.ndarray'>
# Iters. done: 39 [Current cost: -0.6637917799999999]
# <class 'numpy.ndarray'>
# Iters. done: 40 [Current cost: -0.66932806]
# <class 'numpy.ndarray'>
# Iters. done: 41 [Current cost: -0.67555244]
# <class 'numpy.ndarray'>
# Iters. done: 42 [Current cost: -0.68099904]
# <class 'numpy.ndarray'>
# Iters. done: 43 [Current cost: -0.67067948]
# <class 'numpy.ndarray'>
# Iters. done: 44 [Current cost: -0.6761126599999999]
# <class 'numpy.ndarray'>
# Iters. done: 45 [Current cost: -0.67915192]
# <class 'numpy.ndarray'>
# Iters. done: 46 [Current cost: -0.6835375600000001]
# <class 'numpy.ndarray'>
# Iters. done: 47 [Current cost: -0.6642944000000001]
# <class 'numpy.ndarray'>
# Iters. done: 48 [Current cost: -0.674889]
# <class 'numpy.ndarray'>
# Iters. done: 49 [Current cost: -0.66347348]
# <class 'numpy.ndarray'>
# Iters. done: 50 [Current cost: -0.6726460799999999]
# <class 'numpy.ndarray'>
# Iters. done: 51 [Current cost: -0.69011594]
# <class 'numpy.ndarray'>
# Iters. done: 52 [Current cost: -0.68735378]
# <class 'numpy.ndarray'>
# Iters. done: 53 [Current cost: -0.68457938]
# <class 'numpy.ndarray'>
# Iters. done: 54 [Current cost: -0.68235206]
# <class 'numpy.ndarray'>
# Iters. done: 55 [Current cost: -0.68438792]
# <class 'numpy.ndarray'>
# Iters. done: 56 [Current cost: -0.6845609399999999]
# <class 'numpy.ndarray'>
# Iters. done: 57 [Current cost: -0.68998086]
# <class 'numpy.ndarray'>
# Iters. done: 58 [Current cost: -0.6766455]
# <class 'numpy.ndarray'>
# Iters. done: 59 [Current cost: -0.68471476]
# <class 'numpy.ndarray'>
# Iters. done: 60 [Current cost: -0.67401702]
# <class 'numpy.ndarray'>
# Iters. done: 61 [Current cost: -0.6799139000000001]
# <class 'numpy.ndarray'>
# Iters. done: 62 [Current cost: -0.6799124200000001]
# <class 'numpy.ndarray'>
# Iters. done: 63 [Current cost: -0.67755044]
# <class 'numpy.ndarray'>
# Iters. done: 64 [Current cost: -0.68172924]
# <class 'numpy.ndarray'>
# Iters. done: 65 [Current cost: -0.6821562400000001]
# <class 'numpy.ndarray'>
# Iters. done: 66 [Current cost: -0.67628586]
# <class 'numpy.ndarray'>
# Iters. done: 67 [Current cost: -0.67084182]
# <class 'numpy.ndarray'>
# Iters. done: 68 [Current cost: -0.6761307000000001]
# <class 'numpy.ndarray'>
# Iters. done: 69 [Current cost: -0.67901914]
# <class 'numpy.ndarray'>
# Iters. done: 70 [Current cost: -0.67864908]
# <class 'numpy.ndarray'>
# Iters. done: 71 [Current cost: -0.68343616]
# <class 'numpy.ndarray'>
# Iters. done: 72 [Current cost: -0.6790191999999999]
# <class 'numpy.ndarray'>
# Iters. done: 73 [Current cost: -0.6915131600000001]
# <class 'numpy.ndarray'>
# Iters. done: 74 [Current cost: -0.6761480799999999]
# <class 'numpy.ndarray'>
# Iters. done: 75 [Current cost: -0.6833146600000001]
# <class 'numpy.ndarray'>
# Iters. done: 76 [Current cost: -0.67713668]
# <class 'numpy.ndarray'>
# Iters. done: 77 [Current cost: -0.6845488800000001]
# <class 'numpy.ndarray'>
# Iters. done: 78 [Current cost: -0.67839248]
# <class 'numpy.ndarray'>
# Iters. done: 79 [Current cost: -0.6864423800000001]
# <class 'numpy.ndarray'>
# Iters. done: 80 [Current cost: -0.6791501600000001]
# <class 'numpy.ndarray'>
# Iters. done: 81 [Current cost: -0.68245922]
# <class 'numpy.ndarray'>
# Iters. done: 82 [Current cost: -0.6787780800000001]
# <class 'numpy.ndarray'>
# Iters. done: 83 [Current cost: -0.68125138]
# <class 'numpy.ndarray'>
# Iters. done: 84 [Current cost: -0.6843405600000001]
# <class 'numpy.ndarray'>
# Iters. done: 85 [Current cost: -0.6784933200000001]
# <class 'numpy.ndarray'>
# Iters. done: 86 [Current cost: -0.6850037]
# <class 'numpy.ndarray'>
# Iters. done: 87 [Current cost: -0.6782454]
# <class 'numpy.ndarray'>
# Iters. done: 88 [Current cost: -0.68265362]
# <class 'numpy.ndarray'>
# Iters. done: 89 [Current cost: -0.67675216]
# <class 'numpy.ndarray'>
# Iters. done: 90 [Current cost: -0.6831914800000001]
# <class 'numpy.ndarray'>
# Iters. done: 91 [Current cost: -0.6797321000000001]
# <class 'numpy.ndarray'>
# Iters. done: 92 [Current cost: -0.6835750599999999]
# <class 'numpy.ndarray'>
# Iters. done: 93 [Current cost: -0.6886664600000001]
# <class 'numpy.ndarray'>
# Iters. done: 94 [Current cost: -0.6829419999999999]
# <class 'numpy.ndarray'>
# Iters. done: 95 [Current cost: -0.6854039000000001]
# <class 'numpy.ndarray'>
# Iters. done: 96 [Current cost: -0.6797838199999999]
# <class 'numpy.ndarray'>
# Iters. done: 97 [Current cost: -0.6757681600000001]
# <class 'numpy.ndarray'>
# Iters. done: 98 [Current cost: -0.6745012800000001]
# <class 'numpy.ndarray'>
# Iters. done: 99 [Current cost: -0.6839227600000001]
# <class 'numpy.ndarray'>
# Iters. done: 100 [Current cost: -0.6791875]
# <class 'numpy.ndarray'>
# Iters. done: 101 [Current cost: -0.6785109199999999]
# <class 'numpy.ndarray'>
# Iters. done: 102 [Current cost: -0.6805925]
# <class 'numpy.ndarray'>
# Iters. done: 103 [Current cost: -0.6832058]
# <class 'numpy.ndarray'>
# Iters. done: 104 [Current cost: -0.6762659400000001]
# <class 'numpy.ndarray'>
# Iters. done: 105 [Current cost: -0.67936074]
# <class 'numpy.ndarray'>
# Iters. done: 106 [Current cost: -0.68405864]
# <class 'numpy.ndarray'>
# Iters. done: 107 [Current cost: -0.67573642]
# <class 'numpy.ndarray'>
# Iters. done: 108 [Current cost: -0.67670248]
# <class 'numpy.ndarray'>
# Iters. done: 109 [Current cost: -0.6785317200000001]
# <class 'numpy.ndarray'>
# Iters. done: 110 [Current cost: -0.6783489800000001]
# <class 'numpy.ndarray'>
# Iters. done: 111 [Current cost: -0.6710543]
# <class 'numpy.ndarray'>
# Iters. done: 112 [Current cost: -0.67867572]
# <class 'numpy.ndarray'>
# Iters. done: 113 [Current cost: -0.66756712]
# <class 'numpy.ndarray'>
# Iters. done: 114 [Current cost: -0.6790587800000001]
# <class 'numpy.ndarray'>
# Iters. done: 115 [Current cost: -0.68003712]
# <class 'numpy.ndarray'>
# Iters. done: 116 [Current cost: -0.68057354]
# <class 'numpy.ndarray'>
# Iters. done: 117 [Current cost: -0.6837578400000001]
# <class 'numpy.ndarray'>
# Iters. done: 118 [Current cost: -0.6722249800000001]
# <class 'numpy.ndarray'>
# Iters. done: 119 [Current cost: -0.67354188]
# <class 'numpy.ndarray'>
# Iters. done: 120 [Current cost: -0.6750786400000001]
# <class 'numpy.ndarray'>
# Iters. done: 121 [Current cost: -0.67255726]
# <class 'numpy.ndarray'>
# Iters. done: 122 [Current cost: -0.6743642799999999]
# <class 'numpy.ndarray'>
# Iters. done: 123 [Current cost: -0.6806003199999999]
# <class 'numpy.ndarray'>
# Iters. done: 124 [Current cost: -0.67298602]
# <class 'numpy.ndarray'>
# Iters. done: 125 [Current cost: -0.6717890000000001]
# <class 'numpy.ndarray'>
# Iters. done: 126 [Current cost: -0.6817888400000001]
# <class 'numpy.ndarray'>
# Iters. done: 127 [Current cost: -0.6794678000000001]
# <class 'numpy.ndarray'>
# Iters. done: 128 [Current cost: -0.6781190000000001]
# <class 'numpy.ndarray'>
# Iters. done: 129 [Current cost: -0.68307512]
# <class 'numpy.ndarray'>
# Iters. done: 130 [Current cost: -0.67834532]
# <class 'numpy.ndarray'>
# Iters. done: 131 [Current cost: -0.6830037999999999]
# <class 'numpy.ndarray'>
# Iters. done: 132 [Current cost: -0.6798600800000001]

# %% [markdown]
# At the terminus of this routine we have a result in the standard SciPy `OptimizeResult` format.  From this we see that it took `nfev` number of cost function evaluations to obtain the solution vector of parameter angles (`x`) that, when plugged into the ansatz circuit, yield the approximate ground state solution we were looking for.

# %%
res
# Out:
#  message: Return from COBYLA because the trust region radius reaches its lower bound.
#  success: True
#   status: 0
#      fun: -0.6915131600000001
#        x: [ 6.762e+00  2.117e+00 ...  3.426e+00  3.284e+00]
#     nfev: 132
#    maxcv: 0.0

# %% [markdown]
# ## Step 4: Post-process and return result in desired classical format

# %% [markdown]
# If the procedure terminates correctly, then the `prev_vector` and `iters` values in our `cost_history_dict` dictionary should be equal to the solution vector and total number of function evaluations, respectively.  This is easy to verify:

# %%
all(cost_history_dict["prev_vector"] == res.x)
# Out:
# False

# %%
cost_history_dict["iters"] == res.nfev
# Out:
# np.True_

# %% [markdown]
# We can also now view the progress toward convergence as monitored by the cost history at each iteration:

# %%
fig, ax = plt.subplots()
ax.plot(range(cost_history_dict["iters"]), cost_history_dict["cost_history"])
ax.set_xlabel("Iterations")
ax.set_ylabel("Cost")
plt.draw()

# %% [markdown]
# ## Tutorial survey
#
# Please take this short survey to provide feedback on this tutorial. Your insights will help us improve our content offerings and user experience.
#
# [Link to survey](https://your.feedback.ibm.com/jfe/form/SV_9AizRyKFHEGzVs2)

# %% [markdown]
# © IBM Corp., 2017-2025

# %%
from sympy import symbols, Symbol
from sympy.matrices import Matrix
import sympy as sp

# %%
# p0 = a
# p1 = b
# p2 = c
# m  = m
a, b, c = symbols("p_0, p_1, p_2", real=True)
m = Symbol("m", real=True, positive=True)
x, y = symbols("x, y", real=True)
zero = Matrix([0, 0])

u_matrix = Matrix([[a - m, -b - 1j * c],
                   [b - 1j * c, -a - m]])
u_matrix = u_matrix.subs(a, sp.sqrt(b ** 2 + c ** 2 + m ** 2))
u_matrix
# Out:
# Matrix([
# [-m + sqrt(m**2 + p_1**2 + p_2**2),                  -p_1 - 1.0*I*p_2],
# [                  p_1 - 1.0*I*p_2, -m - sqrt(m**2 + p_1**2 + p_2**2)]])

# %%
u_sol = sp.linsolve((u_matrix, zero),
                    [x, y]
                    )
u_sol
# Out:
# {(y*(-1.0*p_1/(1.0*m - 1.0*sqrt(m**2 + p_1**2 + p_2**2)) - 1.0*I*p_2/(1.0*m - 1.0*sqrt(m**2 + p_1**2 + p_2**2))), y)}

# %%
v_matrix = Matrix([[a + m, -b - 1j * c],
                   [b - 1j * c, -a + m]])
v_matrix = v_matrix.subs(a, sp.sqrt(b ** 2 + c ** 2 + m ** 2))
v_matrix
# Out:
# Matrix([
# [m + sqrt(m**2 + p_1**2 + p_2**2),                 -p_1 - 1.0*I*p_2],
# [                 p_1 - 1.0*I*p_2, m - sqrt(m**2 + p_1**2 + p_2**2)]])

# %%
v_sol = sp.linsolve((v_matrix, zero),
                    [x, y]
                    )
v_sol
# Out:
# {(y*(1.0*p_1/(1.0*m + 1.0*sqrt(m**2 + p_1**2 + p_2**2)) + 1.0*I*p_2/(1.0*m + 1.0*sqrt(m**2 + p_1**2 + p_2**2))), y)}

# %%
u = Matrix(*u_sol)
v = Matrix(*v_sol)
u_dagger = u.transpose().conjugate()
v_dagger = v.transpose().conjugate()
u_bar = u_dagger * Matrix([[1, 0],
                           [0, -1]])
v_bar = v_dagger * Matrix([[1, 0],
                           [0, -1]])

# %% [markdown]
# # Norm u

# %%
test_u_norm = u_bar * u
test_u_norm.simplify()
test_u_norm[0, 0]
# Out:
# 1.0*y**2*(-(m - sqrt(m**2 + p_1**2 + p_2**2))**2 + (p_1 - I*p_2)*(p_1 + I*p_2))/(m - sqrt(m**2 + p_1**2 + p_2**2))**2

# %%
y_2_u = 2 * m / (test_u_norm[0, 0] / y ** 2)
y_2_u
# Out:
# 2.0*m*(m - sqrt(m**2 + p_1**2 + p_2**2))**2/(-(m - sqrt(m**2 + p_1**2 + p_2**2))**2 + (p_1 - I*p_2)*(p_1 + I*p_2))

# %%
test_u_norm.subs(y ** 2, y_2_u)[0, 0]
# Out:
# 2.0*m

# %% [markdown]
# This choice of norm results in the usual convention of $\bar{u} u = 2m$

# %%
test = (u_dagger * u).subs(y ** 2, y_2_u)
test.simplify()
test[0, 0]
# Out:
# 2.0*(-m**2 + m*sqrt(m**2 + p_1**2 + p_2**2) - p_1**2 - p_2**2)/(m - sqrt(m**2 + p_1**2 + p_2**2))

# %% [markdown]
# This choice of norm results in the usual convention of $u^\dagger u = 2E_p$

# %%
u = u.subs(y, sp.sqrt(y_2_u))
u.simplify()
u_dagger = u_dagger.subs(y, sp.sqrt(y_2_u))
u_dagger.simplify()
u_bar = u_bar.subs(y, sp.sqrt(y_2_u))
u_bar.simplify()

# %% [markdown]
# # Norm v

# %%
test_v_norm = v_bar * v
test_v_norm.simplify()
test_v_norm[0, 0]
# Out:
# 1.0*y**2*(-(m + sqrt(m**2 + p_1**2 + p_2**2))**2 + (p_1 - I*p_2)*(p_1 + I*p_2))/(m + sqrt(m**2 + p_1**2 + p_2**2))**2

# %%
y_2_v = -2 * m / (test_v_norm[0, 0] / y ** 2)
y_2_v
# Out:
# -2.0*m*(m + sqrt(m**2 + p_1**2 + p_2**2))**2/(-(m + sqrt(m**2 + p_1**2 + p_2**2))**2 + (p_1 - I*p_2)*(p_1 + I*p_2))

# %%
test_v_norm.subs(y ** 2, y_2_v)[0, 0]
# Out:
# -2.0*m

# %% [markdown]
# This choice of norm results in the usual convention of $\bar{v} v = -2m$

# %%
test = (v_dagger * v).subs(y ** 2, y_2_v)
test.simplify()
test[0, 0]
# Out:
# 2.0*(m**2 + m*sqrt(m**2 + p_1**2 + p_2**2) + p_1**2 + p_2**2)/(m + sqrt(m**2 + p_1**2 + p_2**2))

# %% [markdown]
# This choice of norm results in the usual convention of $v^\dagger v = 2E_p$

# %%
v = v.subs(y, sp.sqrt(y_2_v))
v.simplify()
v_dagger = v_dagger.subs(y, sp.sqrt(y_2_v))
v_dagger.simplify()
v_bar = v_bar.subs(y, sp.sqrt(y_2_v))
v_bar.simplify()

# %%
u
# Out:
# Matrix([
# [0.707106781186548*sqrt(2)*sqrt(-1/(m - sqrt(m**2 + p_1**2 + p_2**2)))*(-p_1 - I*p_2)*Abs(m - sqrt(m**2 + p_1**2 + p_2**2))/(m - sqrt(m**2 + p_1**2 + p_2**2))],
# [                                                  0.707106781186548*sqrt(2)*sqrt(-1/(m - sqrt(m**2 + p_1**2 + p_2**2)))*Abs(m - sqrt(m**2 + p_1**2 + p_2**2))]])

# %%
v
# Out:
# Matrix([
# [0.707106781186548*sqrt(2)*(p_1 + I*p_2)/sqrt(m + sqrt(m**2 + p_1**2 + p_2**2))],
# [                  0.707106781186548*sqrt(2*m + 2*sqrt(m**2 + p_1**2 + p_2**2))]])

# %%
temp = v_matrix*Matrix([[0,1],[1,0]])*u.conjugate()
temp.simplify()
temp
# Out:
# Matrix([
# [0],
# [0]])

# %%
temp = u_matrix*Matrix([[0,1],[1,0]])*v.conjugate()
temp.simplify()
temp
# Out:
# Matrix([
# [0],
# [0]])
